# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('UberDataset.csv')
dataset
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
dataset.shape
# Out:
# (1156, 7)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# # Data Pre-processing

# %%
dataset['PURPOSE'].fillna('NOT', inplace = True)
dataset
# Out:
# C:\Users\dv240\AppData\Local\Temp\ipykernel_17040\2883815702.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['PURPOSE'].fillna('NOT', inplace = True)
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# ...

# %%
dataset['START_DATE'] = pd.to_datetime(dataset['START_DATE'], errors = 'coerce')

# %%
dataset['END_DATE'] = pd.to_datetime(dataset['END_DATE'], errors = 'coerce')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
from datetime import datetime

dataset['s_date'] = pd.DatetimeIndex(dataset['START_DATE']).date
dataset['s_time'] = pd.DatetimeIndex(dataset['START_DATE']).hour
dataset['e_date'] = pd.DatetimeIndex(dataset['END_DATE']).date
dataset['e_time'] = pd.DatetimeIndex(dataset['END_DATE']).hour

# %%
dataset['time_of_the_day'] = pd.cut(x=dataset['s_time'],bins=[0,10,15,19,24],labels = ['Morning','Afternoon','Evening','Night'])

# %%
dataset
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151                 NaT                 NaT  Business           Kar?chi
# 1152                 NaT                 NaT  Business  Unknown Location
# 1153                 NaT                 NaT  Business        Katunayake
# 1154                 NaT                 NaT  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                   STOP    MILES          PURPOSE      s_date  s_time  \
# ...

# %%
dataset.dropna(inplace = True)

# %%
dataset.shape
# Out:
# (413, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 413 entries, 0 to 1047
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   START_DATE       413 non-null    datetime64[ns]
#  1   END_DATE         413 non-null    datetime64[ns]
#  2   CATEGORY         413 non-null    object
#  3   START            413 non-null    object
#  4   STOP             413 non-null    object
#  5   MILES            413 non-null    float64
#  6   PURPOSE          413 non-null    object
#  7   s_date           413 non-null    object
#  8   s_time           413 non-null    float64
#  9   e_date           413 non-null    object
#  10  e_time           413 non-null    float64
#  11  time_of_the_day  413 non-null    category
# dtypes: category(1), datetime64[ns](2), float64(3), object(6)
# memory usage: 39.3+ KB

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE      s_date  s_time      e_date  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21.0  2016-01-01
# 1      Fort Pierce    5.0              NOT  2016-01-02     1.0  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20.0  2016-01-02
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17.0  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14.0  2016-01-06
#
#    e_time time_of_the_day
# 0    21.0           Night
# 1     1.0         Morning
# 2    20.0           Night
# ...

# %% [markdown]
# # Data visualization

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)

sns.countplot(dataset['CATEGORY'])
plt.xticks(rotation=90)

plt.subplot(1,2,2)
sns.countplot(dataset['PURPOSE'])
# Out:
# <Axes: xlabel='count', ylabel='PURPOSE'>

# %%
sns.countplot(dataset['time_of_the_day'])
# Out:
# <Axes: xlabel='count', ylabel='time_of_the_day'>

# %%
dataset['month'] = pd.DatetimeIndex(dataset['s_date']).month
month_label = {
    1 : "January",
    2 : "February",
    3 : "March",
    4 : "April",
    5 : "May",
    6 : "June",
    7 : "July",
    8 : "August",
    9 : "September",
    10 : "October",
    11 : "November",
    12 : "December"
}

dataset['month'] = dataset.month.map(month_label)

mon = dataset.month.value_counts(sort = False)

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE      s_date  s_time      e_date  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21.0  2016-01-01
# 1      Fort Pierce    5.0              NOT  2016-01-02     1.0  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20.0  2016-01-02
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17.0  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14.0  2016-01-06
#
#    e_time time_of_the_day    month
# 0    21.0           Night  January
# 1     1.0         Morning  January
# ...

# %%
df = pd.DataFrame({
    "Months" : mon.values,
    "Miles_Count" : dataset.groupby('month',sort=False)['MILES'].max()
})

# df['Months'].idxmax()
# df['Miles_Count'].idxmax()
# Out:
# 'April'

# %%
p = sns.lineplot(data = df)
p.set(xlabel = "Months", ylabel = "Miles_count")


plt.xticks(rotation = 45)
plt.show()

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE      s_date  s_time      e_date  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01    21.0  2016-01-01
# 1      Fort Pierce    5.0              NOT  2016-01-02     1.0  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02    20.0  2016-01-02
# 3      Fort Pierce    4.7          Meeting  2016-01-05    17.0  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06    14.0  2016-01-06
#
#    e_time time_of_the_day    month
# 0    21.0           Night  January
# 1     1.0         Morning  January
# ...

# %%
dataset['s_date'] = pd.to_datetime(dataset['s_date'])
dataset['week_day'] = dataset['s_date'].dt.weekday

day_label = {
    0 : "Monday",
    1 : "Tuesday",
    2 : "Wednesday",
    3 : "Thursday",
    4 : "Friday",
    5 : "Saturday",
    6 : "Sunday"
}

dataset['week_day'] = dataset['week_day'].map(day_label)

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE     s_date  s_time      e_date  \
# 0      Fort Pierce    5.1   Meal/Entertain 2016-01-01    21.0  2016-01-01
# 1      Fort Pierce    5.0              NOT 2016-01-02     1.0  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies 2016-01-02    20.0  2016-01-02
# 3      Fort Pierce    4.7          Meeting 2016-01-05    17.0  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit 2016-01-06    14.0  2016-01-06
#
#    e_time time_of_the_day    month   week_day
# 0    21.0           Night  January     Friday
# ...

# %%
day_label = dataset.week_day.value_counts()

sns.barplot(x = day_label.index, y = day_label)
plt.xlabel('Day')
plt.ylabel('Counts')

plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Friday'),
#   Text(1, 0, 'Thursday'),
#   Text(2, 0, 'Monday'),
#   Text(3, 0, 'Tuesday'),
#   Text(4, 0, 'Saturday'),
#   Text(5, 0, 'Wednesday'),
#   Text(6, 0, 'Sunday')])

# %%
dataset.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE     s_date  s_time      e_date  \
# 0      Fort Pierce    5.1   Meal/Entertain 2016-01-01    21.0  2016-01-01
# 1      Fort Pierce    5.0              NOT 2016-01-02     1.0  2016-01-02
# 2      Fort Pierce    4.8  Errand/Supplies 2016-01-02    20.0  2016-01-02
# 3      Fort Pierce    4.7          Meeting 2016-01-05    17.0  2016-01-05
# 4  West Palm Beach   63.7   Customer Visit 2016-01-06    14.0  2016-01-06
#
#    e_time time_of_the_day    month   week_day
# 0    21.0           Night  January     Friday
# ...

# %%
sns.boxplot(dataset['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(dataset[dataset["MILES"] < 100 ]['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(dataset[dataset["MILES"] < 40 ]['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.displot(dataset[dataset['MILES'] < 40 ]['MILES'])
